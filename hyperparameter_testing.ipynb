# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('results.csv', sep=', ')
df['activation'] = df['activation'].apply(lambda x: {'tanh':0, 'relu':1, 'elu':2}[x])
print(df)
# Out:
# run  mem_length            lr  activation  hidden_layer_size  \
# 0     0        1000  1.000000e-03           2                 20
# 1     2        1000  1.000000e-08           1                 20
# 2     3        5000  1.000000e-09           1                 50
# 3     4        5000  1.000000e-05           0                 20
# 4     5         500  1.000000e-08           2                 50
# 5     6        1000  1.000000e-04           1                100
# 6     7         100  1.000000e-09           2                125
# 7     8        2000  1.000000e-04           0                 20
# 8     9        5000  1.000000e-07           0                 50
# 9    11         500  1.000000e-02           0                100
# 10   13         500  1.000000e-04           0                500
# 11   14        5000  1.000000e-05           0                 50
# 12   15         500  1.000000e-08           2                 50
# ...

# %%
plt.xscale('log')
plt.yscale('log')
plt.scatter(df['mem_length'], df['mean'], s=2)
plt.show()
plt.xscale('log')
plt.yscale('log')
plt.scatter(df['lr'], df['mean'], s=2)
plt.show()
plt.yscale('log')
plt.scatter(df['activation'], df['mean'], s=2)
plt.show()
plt.xscale('log')
plt.yscale('log')
plt.scatter(df['hidden_layer_size'], df['mean'], s=2)
plt.show()
plt.xscale('log')
plt.yscale('log')
plt.scatter(df['data_extraction_size'], df['mean'], s=2)
plt.show()
plt.xscale('log')
plt.yscale('log')
plt.scatter(df['block_count'], df['mean'], s=2)
